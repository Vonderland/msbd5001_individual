# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
import warnings
warnings.filterwarnings('ignore')

pd.options.display.max_columns = 12

# use this path to run on kaggle
# train_path = "../input/msbd5001-fall2019/train.csv"
# test_path = "../input/msbd5001-fall2019/test.csv"

# use this path to run on local
train_path = "../data/train.csv"
test_path = "../data/test.csv"

# %%
train = pd.read_csv(train_path)
train = train.drop(columns=['id'])
train
# Out:
#      playtime_forever  is_free    price  \
# 0            0.000000    False   3700.0
# 1            0.016667     True      0.0
# 2            0.000000    False   5000.0
# 3            1.533333    False   9900.0
# 4           22.333333    False   4800.0
# 5            2.933333    False  25800.0
# 6            2.616667    False   3600.0
# 7            0.150000     True      0.0
# 8            0.016667    False   4000.0
# 9            0.016667    False   8800.0
# 10           0.000000    False   6800.0
# 11           0.000000    False   2500.0
# 12           0.000000     True      0.0
# 13          20.566667    False   3300.0
# 14           0.633333    False   5700.0
# 15           0.016667     True      0.0
# 16           3.300000    False   6800.0
# 17           0.000000    False  11200.0
# 18           0.000000    False  11200.0
# 19           0.000000    False   3600.0
# 20           0.166667    False   6800.0
# 21           1.616667    False   8800.0
# 22           0.000000    False   8800.0
# 23           0.050000     True      0.0
# 24           0.000000    False  12900.0
# 25           0.000000    False   9900.0
# 26           0.216667    False   1500.0
# 27           0.000000    False   4800.0
# 28           0.000000    False   4800.0
# 29           4.216667    False   6800.0
# ..                ...      ...      ...
# 327          0.000000    False   4800.0
# 328          0.000000    False   1800.0
# 329          2.383333    False  24800.0
# 330          0.000000    False   6800.0
# 331          2.533333    False   8800.0
# 332          0.316667     True      0.0
# 333          0.000000    False   4800.0
# 334          0.000000    False  11800.0
# 335          0.000000    False   2500.0
# 336          0.683333    False   4800.0
# 337          0.000000    False   9900.0
# 338          0.000000    False   5000.0
# 339          5.883333    False   3600.0
# 340          0.083333    False   4000.0
# 341          0.616667     True      0.0
# 342          1.116667    False   7900.0
# 343          0.000000    False   7900.0
# 344          0.050000    False   4800.0
# 345         63.800000    False   8000.0
# 346          0.000000    False   3600.0
# 347         23.633333    False  20800.0
# 348          0.000000    False   2000.0
# 349          0.333333    False   4800.0
# 350          2.450000    False   3700.0
# 351          0.000000    False   5000.0
# 352          0.783333    False   8800.0
# 353          0.000000    False   6800.0
# 354          0.000000    False   8300.0
# 355          0.000000    False   6800.0
# 356          0.000000    False  10000.0
#
#                                                 genres  \
# 0                               Adventure,Casual,Indie
# 1                                                  RPG
# 2                               Adventure,Casual,Indie
# 3                                           Action,RPG
# 4                                Action,Indie,Strategy
# 5                                                  RPG
# 6                                         Action,Indie
# 7                                           Simulation
# 8                                        Adventure,RPG
# 9                                     Action,Adventure
# 10                                    Action,Adventure
# 11                        Adventure,Indie,RPG,Strategy
# 12                                              Action
# 13                          Action,Adventure,Indie,RPG
# 14                      Action,Casual,Indie,Simulation
# 15                       Adventure,Simulation,Strategy
# 16                          Action,Adventure,Indie,RPG
# 17                                    Indie,Simulation
# 18                                 Simulation,Strategy
# 19                           Indie,Simulation,Strategy
# 20                                              Racing
# 21                                        RPG,Strategy
# 22                              Action,Adventure,Indie
# 23                                        Casual,Indie
# 24                                            Strategy
# 25                                                 RPG
# 26                      Adventure,Indie,RPG,Simulation
# 27                                           Adventure
# 28                           Indie,Simulation,Strategy
# 29                                        Action,Indie
# ..                                                 ...
# 327                                                RPG
# 328                                Adventure,Indie,RPG
# 329                                   Action,Adventure
# 330                                             Action
# 331                                    Adventure,Indie
# 332  Adventure,Casual,Free to Play,Massively Multip...
# 333                                       Action,Indie
# 334                               Action,Adventure,RPG
# 335                                          Adventure
# 336                                             Action
# 337                                             Action
# 338                                          Adventure
# 339                                    Adventure,Indie
# 340                                       Action,Indie
# 341                                 Free to Play,Indie
# 342                                    Adventure,Indie
# 343                                    Adventure,Indie
# 344                       Adventure,Indie,RPG,Strategy
# 345                                     Indie,Strategy
# 346                                Adventure,Indie,RPG
# 347                                   Action,Adventure
# 348                             Adventure,Casual,Indie
# 349                                   Action,Indie,RPG
# 350                                             Action
# 351                         Action,Adventure,Indie,RPG
# 352                                  Action,Simulation
# 353                                   Action,Adventure
# 354                               Action,Adventure,RPG
# 355                                   Action,Adventure
# 356                                     Indie,Strategy
#
#                                             categories  \
# 0        Single-player,Steam Trading Cards,Steam Cloud
# 1             Single-player,Partial Controller Support
# 2    Single-player,Full controller support,Steam Tr...
# 3    Single-player,Multi-player,Steam Achievements,...
# 4    Single-player,Co-op,Steam Achievements,Full co...
# 5    Single-player,Online Co-op,Local Co-op,Shared/...
# 6    Single-player,Steam Achievements,Steam Trading...
# 7    Single-player,Multi-player,Online Multi-Player...
# 8    Single-player,Steam Achievements,Steam Trading...
# 9    Single-player,Steam Achievements,SteamVR Colle...
# 10   Single-player,Steam Achievements,Partial Contr...
# 11                           Single-player,Steam Cloud
# 12   Single-player,Multi-player,Online Multi-Player...
# 13   Single-player,Multi-player,Online Multi-Player...
# 14   Single-player,Local Multi-Player,Local Co-op,S...
# 15   Single-player,Multi-player,Co-op,Valve Anti-Ch...
# 16   Single-player,Multi-player,Co-op,Cross-Platfor...
# 17   Single-player,Steam Trading Cards,Steam Worksh...
# 18   Single-player,Multi-player,Cross-Platform Mult...
# 19   Single-player,Multi-player,Steam Achievements,...
# 20   Single-player,Multi-player,Steam Achievements,...
# 21   Single-player,Multi-player,Online Multi-Player...
# 22   Single-player,Steam Achievements,Full controll...
# 23               Single-player,Full controller support
# 24   Single-player,Multi-player,Online Multi-Player...
# 25                                       Single-player
# 26   Single-player,Steam Achievements,Full controll...
# 27   Single-player,Steam Achievements,Full controll...
# 28      Single-player,Multi-player,Steam Trading Cards
# 29   Single-player,Local Co-op,Shared/Split Screen,...
# ..                                                 ...
# 327                                      Single-player
# 328  Single-player,Steam Achievements,Steam Trading...
# 329  Single-player,Steam Achievements,Steam Trading...
# 330  Single-player,Steam Achievements,Full controll...
# 331  Single-player,Local Co-op,Shared/Split Screen,...
# 332  Single-player,Multi-player,Online Multi-Player...
# 333  Single-player,Local Co-op,Steam Achievements,F...
# 334  Single-player,Steam Achievements,Full controll...
# 335      Single-player,Steam Trading Cards,Steam Cloud
# 336      Single-player,VR Support,SteamVR Collectibles
# 337  Single-player,Steam Achievements,Full controll...
# 338  Single-player,Steam Achievements,Full controll...
# 339  Single-player,Steam Achievements,Steam Trading...
# 340  Single-player,Steam Achievements,Full controll...
# 341              Single-player,Full controller support
# 342  Single-player,Steam Achievements,Steam Trading...
# 343  Single-player,Steam Achievements,Steam Trading...
# 344  Single-player,Steam Trading Cards,Steam Worksh...
# 345  Single-player,Steam Achievements,Full controll...
# 346  Single-player,Steam Achievements,Steam Trading...
# 347  Single-player,Multi-player,Co-op,Steam Trading...
# 348  Single-player,Steam Achievements,Steam Trading...
# 349  Single-player,Local Multi-Player,Local Co-op,S...
# 350  Single-player,Multi-player,Co-op,Steam Achieve...
# 351  Single-player,Steam Achievements,Full controll...
# 352  Single-player,Multi-player,Online Multi-Player...
# 353  Single-player,Steam Achievements,Full controll...
# 354  Single-player,Steam Achievements,Full controll...
# 355  Single-player,Steam Achievements,Full controll...
# 356  Single-player,Multi-player,Co-op,Shared/Split ...
#
#                                                   tags purchase_date  \
# 0    Indie,Adventure,Story Rich,Casual,Atmospheric,...   Jul 2, 2018
# 1    Mod,Utilities,RPG,Game Development,Singleplaye...  Nov 26, 2016
# 2    Point & Click,Adventure,Story Rich,Comedy,Indi...   Jul 2, 2018
# 3    Medieval,RPG,Open World,Strategy,Sandbox,Actio...  Nov 28, 2016
# 4    Tower Defense,Co-op,Action,Strategy,Online Co-...   Mar 4, 2018
# 5    RPG,Open World,Survival,Co-op,Fantasy,Online C...           NaN
# 6    Great Soundtrack,Action,Violent,Indie,Top-Down...  Feb 16, 2018
# 7                  VR,Simulation,Utilities,Multiplayer  Jan 29, 2018
# 8    RPG,Turn-Based,Adventure,Fantasy,Great Soundtr...  Nov 23, 2018
# 9    Action,Adventure,VR,Shooter,Puzzle,FPS,First-P...  Dec 22, 2017
# 10   Action,Adventure,Hack and Slash,Third Person,S...  Jan 30, 2018
# 11   RPG,Post-apocalyptic,Classic,Turn-Based,Advent...  Jun 23, 2017
# 12                               Action,VR,Multiplayer  Jul 20, 2019
# 13   Action,Multiplayer,Adventure,Rogue-like,Co-op,...   Oct 9, 2016
# 14   Local Co-Op,Local Multiplayer,Co-op,Multiplaye...  Jun 13, 2018
# 15   Space,Simulation,Free to Play,Multiplayer,Onli...  Sep 16, 2017
# 16   RPG,Action RPG,Hack and Slash,Co-op,Dungeon Cr...  Jan 13, 2018
# 17   Space,Simulation,Sandbox,Physics,Science,Space...  May 30, 2019
# 18   Space,Strategy,Grand Strategy,Sci-fi,4X,Real-T...  Feb 18, 2018
# 19   Strategy,Indie,Simulation,Space,Sci-fi,Moddabl...  Dec 21, 2018
# 20   Racing,Offroad,Motocross,Multiplayer,Sports,Si...  Jan 30, 2018
# 21   Strategy,4X,Turn-Based,Turn-Based Strategy,Fan...  Nov 28, 2016
# 22   Atmospheric,Psychological,Story Rich,Female Pr...  May 16, 2018
# 23                        Casual,Indie,VR,Free to Play  Nov 19, 2017
# 24   Strategy,Space,Sci-fi,4X,Multiplayer,Turn-Base...   Apr 2, 2019
# 25   RPG,Sci-fi,Story Rich,Third-Person Shooter,Act...   May 9, 2018
# 26   Choices Matter,Medieval,Card Game,Indie,Choose...   Dec 9, 2017
# 27   Adventure,Point & Click,Classic,Comedy,Story R...  Jun 27, 2019
# 28   Strategy,Simulation,Indie,Sci-fi,Space,2D,Sand...  Dec 21, 2018
# 29   Difficult,Cartoon,Great Soundtrack,Platformer,...   Oct 2, 2017
# ..                                                 ...           ...
# 327  RPG,Open World,Hack and Slash,Action RPG,Multi...   Apr 4, 2017
# 328  Visual Novel,Adventure,Indie,RPG,Choices Matte...  Mar 15, 2018
# 329  Adventure,Action,Open World,Sci-fi,Remake,Thir...  Oct 30, 2018
# 330  Action,Sci-fi,Platformer,Metroidvania,Comedy,S...   May 9, 2018
# 331  Cute,3D Platformer,Great Soundtrack,Female Pro...  Jun 28, 2019
# 332  Early Access,VR,Free to Play,Memes,Anime,Funny...  Feb 27, 2018
# 333  Action,Top-Down,Beat 'em up,Indie,Gore,Fightin...  Jun 27, 2019
# 334  RPG,Comedy,Adventure,Funny,Turn-Based,Dark Hum...  Jun 28, 2019
# 335  Point & Click,Adventure,Classic,Horror,Retro,B...  Feb 27, 2019
# 336  VR,Action,Space,Great Soundtrack,Shooter,First...  Nov 19, 2017
# 337  Stealth,Action,First-Person,Female Protagonist...  Jul 24, 2019
# 338  Batman,Superhero,Story Rich,Choices Matter,Adv...   Feb 5, 2018
# 339  Adventure,Point & Click,Comedy,Puzzle,Singlepl...   Nov 9, 2016
# 340  Action,Indie,Twin Stick Shooter,VR,Platformer,...   Mar 4, 2018
# 341  Free to Play,Walking Simulator,First-Person,In...   Dec 3, 2016
# 342  Adventure,Point & Click,Comedy,Singleplayer,Pu...  Nov 13, 2016
# 343  Adventure,Point & Click,Indie,Female Protagoni...  Apr 21, 2018
# 344  RPG,Cyberpunk,Turn-Based,Isometric,Sci-fi,Indi...  Oct 28, 2017
# 345  Card Game,Rogue-like,Turn-Based,Strategy,Singl...   Dec 4, 2017
# 346  Story Rich,Indie,Great Soundtrack,RPGMaker,Adv...  Feb 27, 2019
# 347  Open World,Shooter,Action,Co-op,Multiplayer,Ta...  Feb 16, 2018
# 348  Adventure,Indie,Interactive Fiction,Casual,Bas...  Mar 28, 2019
# 349  Pixel Graphics,Zombies,Action,Rogue-like,Survi...  Mar 25, 2017
# 350  Quick-Time Events,Rome,Action,Hack and Slash,T...  Jan 23, 2018
# 351  Indie,Adventure,Action,Action-Adventure,Explor...  Nov 17, 2018
# 352                        Simulation,Action,VR,Flight  Nov 24, 2017
# 353  Batman,Action,Open World,Superhero,Stealth,Adv...  Aug 15, 2018
# 354  Action,Hack and Slash,Adventure,RPG,Open World...  Jan 30, 2018
# 355  Action,FPS,Adventure,Shooter,Cyberpunk,Robots,...  Sep 23, 2017
# 356  Strategy,Turn-Based Strategy,Indie,Grand Strat...   Mar 5, 2018
#
#      release_date  total_positive_reviews  total_negative_reviews
# 0    10 Dec, 2013                   372.0                    96.0
# 1    12 Aug, 2015                    23.0                     0.0
# 2    28 Jan, 2014                  3018.0                   663.0
# 3    31 Mar, 2010                 63078.0                  1746.0
# 4    30 Jul, 2012                  8841.0                   523.0
# 5    26 Mar, 2019                     NaN                     NaN
# 6    23 Oct, 2012                 39776.0                  1035.0
# 7    28 Apr, 2016                    33.0                     3.0
# 8    25 Feb, 2014                  1875.0                    39.0
# 9    17 Oct, 2017                    47.0                    11.0
# 10   23 Sep, 2010                  5893.0                   700.0
# 11   13 Nov, 2013                   148.0                    35.0
# 12   11 Dec, 2018                   110.0                   260.0
# 13   31 Aug, 2016                  9659.0                  1058.0
# 14    3 Aug, 2016                  5871.0                   551.0
# 15    6 Jul, 2010                   167.0                    30.0
# 16   20 Sep, 2012                 21566.0                  1289.0
# 17   27 Apr, 2015                 43103.0                  4042.0
# 18    9 May, 2016                 30934.0                  7777.0
# 19   16 Apr, 2015                    74.0                   115.0
# 20   26 Nov, 2010                  1122.0                   248.0
# 21   18 Sep, 2014                  8406.0                  1780.0
# 22    7 Aug, 2017                 20437.0                  1847.0
# 23    3 Jun, 2016                     2.0                     0.0
# 24   18 May, 2017                  6812.0                  1458.0
# 25   28 Jan, 2010                  9566.0                   517.0
# 26   11 Aug, 2016                  5001.0                   597.0
# 27   26 Jan, 2015                  3457.0                   372.0
# 28   16 Nov, 2009                   329.0                    73.0
# 29   29 Sep, 2017                 36322.0                  1542.0
# ..            ...                     ...                     ...
# 327  21 Dec, 2012                   845.0                   333.0
# 328  10 Jul, 2014                  1688.0                   233.0
# 329  14 Nov, 2017                   251.0                    35.0
# 330  25 Jul, 2016                   378.0                    42.0
# 331   5 Oct, 2017                 15943.0                   296.0
# 332   1 Feb, 2017                   135.0                    29.0
# 333   1 Aug, 2017                   854.0                   204.0
# 334   5 Mar, 2014                 27271.0                   741.0
# 335  17 Oct, 2013                   730.0                    90.0
# 336  12 Oct, 2017                  1949.0                    94.0
# 337  14 Sep, 2017                  2292.0                   463.0
# 338   2 Aug, 2016                  5034.0                  1589.0
# 339   6 Aug, 2012                  5641.0                   687.0
# 340   3 Sep, 2015                    58.0                     0.0
# 341  31 May, 2016                    42.0                    32.0
# 342   6 Nov, 2012                  1142.0                   108.0
# 343   2 Jul, 2015                   609.0                    92.0
# 344  25 Jul, 2013                  6383.0                   833.0
# 345  23 Jan, 2019                 31062.0                  1077.0
# 346  10 May, 2017                  1975.0                    44.0
# 347   6 Mar, 2017                 23338.0                  7681.0
# 348  25 Apr, 2013                   263.0                    63.0
# 349  21 Jul, 2016                  3083.0                   202.0
# 350  10 Oct, 2014                 11922.0                  2303.0
# 351   5 May, 2017                   106.0                    23.0
# 352  20 Dec, 2016                   150.0                    91.0
# 353  23 Jun, 2015                 19008.0                  4849.0
# 354   5 Nov, 2015                  5099.0                  1719.0
# 355   3 Jun, 2016                   718.0                   159.0
# 356   5 Dec, 2013                   915.0                   102.0
#
# [357 rows x 10 columns]

# %%
test_with_id = pd.read_csv(test_path)
test = test_with_id.drop(columns=['id'])

# %%
train['total_positive_reviews'] = train[['total_positive_reviews']].fillna(train[['total_positive_reviews']].mean())
test['total_positive_reviews'] = test[['total_positive_reviews']].fillna(test[['total_positive_reviews']].mean())

train['total_negative_reviews'] = train[['total_negative_reviews']].fillna(train[['total_negative_reviews']].mean())
test['total_negative_reviews'] = test[['total_negative_reviews']].fillna(test[['total_negative_reviews']].mean())

# feature engineering: calculate waiting days and own days
train['purchase_date'] = train['purchase_date'].fillna("Jun 27, 2019")
test['purchase_date'] = test['purchase_date'].fillna("Oct 25, 2017")

# %%
# def extract_date(df, column):
#     df[column + '_year'] = pd.to_datetime(df[column]).dt.year
#     df[column + '_month'] = pd.to_datetime(df[column]).dt.month
# #     df[column + '_day'] = pd.to_datetime(df[column]).dt.day

# extract_date(train, "purchase_date")
# extract_date(test, "purchase_date")
# extract_date(train, "release_date")
# extract_date(test, "release_date")

train["waiting_days"] = pd.to_datetime(train['purchase_date']) - pd.to_datetime(train['release_date'])
test["waiting_days"] = pd.to_datetime(test['purchase_date']) - pd.to_datetime(test['release_date'])
train["own_days"] =  pd.to_datetime('Dec 25, 2019')- pd.to_datetime(train['purchase_date'])
test["own_days"] = pd.to_datetime('Dec 25, 2019')- pd.to_datetime(test['purchase_date'])

train["waiting_days"] = pd.to_timedelta(train["waiting_days"]).dt.days
test["waiting_days"] = pd.to_timedelta(test["waiting_days"]).dt.days
train["own_days"] = pd.to_timedelta(train["own_days"]).dt.days
test["own_days"] = pd.to_timedelta(test["own_days"]).dt.days

# because of the mode to fillna, some days maybe illegal, set them to 0
train.waiting_days[train["waiting_days"] < 0] = 0
test.waiting_days[test["waiting_days"] < 0] = 0
train.own_days[train["own_days"] < 0] = 0
test.own_days[test["own_days"] < 0] = 0

# %%
train
# Out:
#      playtime_forever  is_free    price  \
# 0            0.000000    False   3700.0
# 1            0.016667     True      0.0
# 2            0.000000    False   5000.0
# 3            1.533333    False   9900.0
# 4           22.333333    False   4800.0
# 5            2.933333    False  25800.0
# 6            2.616667    False   3600.0
# 7            0.150000     True      0.0
# 8            0.016667    False   4000.0
# 9            0.016667    False   8800.0
# 10           0.000000    False   6800.0
# 11           0.000000    False   2500.0
# 12           0.000000     True      0.0
# 13          20.566667    False   3300.0
# 14           0.633333    False   5700.0
# 15           0.016667     True      0.0
# 16           3.300000    False   6800.0
# 17           0.000000    False  11200.0
# 18           0.000000    False  11200.0
# 19           0.000000    False   3600.0
# 20           0.166667    False   6800.0
# 21           1.616667    False   8800.0
# 22           0.000000    False   8800.0
# 23           0.050000     True      0.0
# 24           0.000000    False  12900.0
# 25           0.000000    False   9900.0
# 26           0.216667    False   1500.0
# 27           0.000000    False   4800.0
# 28           0.000000    False   4800.0
# 29           4.216667    False   6800.0
# ..                ...      ...      ...
# 327          0.000000    False   4800.0
# 328          0.000000    False   1800.0
# 329          2.383333    False  24800.0
# 330          0.000000    False   6800.0
# 331          2.533333    False   8800.0
# 332          0.316667     True      0.0
# 333          0.000000    False   4800.0
# 334          0.000000    False  11800.0
# 335          0.000000    False   2500.0
# 336          0.683333    False   4800.0
# 337          0.000000    False   9900.0
# 338          0.000000    False   5000.0
# 339          5.883333    False   3600.0
# 340          0.083333    False   4000.0
# 341          0.616667     True      0.0
# 342          1.116667    False   7900.0
# 343          0.000000    False   7900.0
# 344          0.050000    False   4800.0
# 345         63.800000    False   8000.0
# 346          0.000000    False   3600.0
# 347         23.633333    False  20800.0
# 348          0.000000    False   2000.0
# 349          0.333333    False   4800.0
# 350          2.450000    False   3700.0
# 351          0.000000    False   5000.0
# 352          0.783333    False   8800.0
# 353          0.000000    False   6800.0
# 354          0.000000    False   8300.0
# 355          0.000000    False   6800.0
# 356          0.000000    False  10000.0
#
#                                                 genres  \
# 0                               Adventure,Casual,Indie
# 1                                                  RPG
# 2                               Adventure,Casual,Indie
# 3                                           Action,RPG
# 4                                Action,Indie,Strategy
# 5                                                  RPG
# 6                                         Action,Indie
# 7                                           Simulation
# 8                                        Adventure,RPG
# 9                                     Action,Adventure
# 10                                    Action,Adventure
# 11                        Adventure,Indie,RPG,Strategy
# 12                                              Action
# 13                          Action,Adventure,Indie,RPG
# 14                      Action,Casual,Indie,Simulation
# 15                       Adventure,Simulation,Strategy
# 16                          Action,Adventure,Indie,RPG
# 17                                    Indie,Simulation
# 18                                 Simulation,Strategy
# 19                           Indie,Simulation,Strategy
# 20                                              Racing
# 21                                        RPG,Strategy
# 22                              Action,Adventure,Indie
# 23                                        Casual,Indie
# 24                                            Strategy
# 25                                                 RPG
# 26                      Adventure,Indie,RPG,Simulation
# 27                                           Adventure
# 28                           Indie,Simulation,Strategy
# 29                                        Action,Indie
# ..                                                 ...
# 327                                                RPG
# 328                                Adventure,Indie,RPG
# 329                                   Action,Adventure
# 330                                             Action
# 331                                    Adventure,Indie
# 332  Adventure,Casual,Free to Play,Massively Multip...
# 333                                       Action,Indie
# 334                               Action,Adventure,RPG
# 335                                          Adventure
# 336                                             Action
# 337                                             Action
# 338                                          Adventure
# 339                                    Adventure,Indie
# 340                                       Action,Indie
# 341                                 Free to Play,Indie
# 342                                    Adventure,Indie
# 343                                    Adventure,Indie
# 344                       Adventure,Indie,RPG,Strategy
# 345                                     Indie,Strategy
# 346                                Adventure,Indie,RPG
# 347                                   Action,Adventure
# 348                             Adventure,Casual,Indie
# 349                                   Action,Indie,RPG
# 350                                             Action
# 351                         Action,Adventure,Indie,RPG
# 352                                  Action,Simulation
# 353                                   Action,Adventure
# 354                               Action,Adventure,RPG
# 355                                   Action,Adventure
# 356                                     Indie,Strategy
#
#                                             categories  \
# 0        Single-player,Steam Trading Cards,Steam Cloud
# 1             Single-player,Partial Controller Support
# 2    Single-player,Full controller support,Steam Tr...
# 3    Single-player,Multi-player,Steam Achievements,...
# 4    Single-player,Co-op,Steam Achievements,Full co...
# 5    Single-player,Online Co-op,Local Co-op,Shared/...
# 6    Single-player,Steam Achievements,Steam Trading...
# 7    Single-player,Multi-player,Online Multi-Player...
# 8    Single-player,Steam Achievements,Steam Trading...
# 9    Single-player,Steam Achievements,SteamVR Colle...
# 10   Single-player,Steam Achievements,Partial Contr...
# 11                           Single-player,Steam Cloud
# 12   Single-player,Multi-player,Online Multi-Player...
# 13   Single-player,Multi-player,Online Multi-Player...
# 14   Single-player,Local Multi-Player,Local Co-op,S...
# 15   Single-player,Multi-player,Co-op,Valve Anti-Ch...
# 16   Single-player,Multi-player,Co-op,Cross-Platfor...
# 17   Single-player,Steam Trading Cards,Steam Worksh...
# 18   Single-player,Multi-player,Cross-Platform Mult...
# 19   Single-player,Multi-player,Steam Achievements,...
# 20   Single-player,Multi-player,Steam Achievements,...
# 21   Single-player,Multi-player,Online Multi-Player...
# 22   Single-player,Steam Achievements,Full controll...
# 23               Single-player,Full controller support
# 24   Single-player,Multi-player,Online Multi-Player...
# 25                                       Single-player
# 26   Single-player,Steam Achievements,Full controll...
# 27   Single-player,Steam Achievements,Full controll...
# 28      Single-player,Multi-player,Steam Trading Cards
# 29   Single-player,Local Co-op,Shared/Split Screen,...
# ..                                                 ...
# 327                                      Single-player
# 328  Single-player,Steam Achievements,Steam Trading...
# 329  Single-player,Steam Achievements,Steam Trading...
# 330  Single-player,Steam Achievements,Full controll...
# 331  Single-player,Local Co-op,Shared/Split Screen,...
# 332  Single-player,Multi-player,Online Multi-Player...
# 333  Single-player,Local Co-op,Steam Achievements,F...
# 334  Single-player,Steam Achievements,Full controll...
# 335      Single-player,Steam Trading Cards,Steam Cloud
# 336      Single-player,VR Support,SteamVR Collectibles
# 337  Single-player,Steam Achievements,Full controll...
# 338  Single-player,Steam Achievements,Full controll...
# 339  Single-player,Steam Achievements,Steam Trading...
# 340  Single-player,Steam Achievements,Full controll...
# 341              Single-player,Full controller support
# 342  Single-player,Steam Achievements,Steam Trading...
# 343  Single-player,Steam Achievements,Steam Trading...
# 344  Single-player,Steam Trading Cards,Steam Worksh...
# 345  Single-player,Steam Achievements,Full controll...
# 346  Single-player,Steam Achievements,Steam Trading...
# 347  Single-player,Multi-player,Co-op,Steam Trading...
# 348  Single-player,Steam Achievements,Steam Trading...
# 349  Single-player,Local Multi-Player,Local Co-op,S...
# 350  Single-player,Multi-player,Co-op,Steam Achieve...
# 351  Single-player,Steam Achievements,Full controll...
# 352  Single-player,Multi-player,Online Multi-Player...
# 353  Single-player,Steam Achievements,Full controll...
# 354  Single-player,Steam Achievements,Full controll...
# 355  Single-player,Steam Achievements,Full controll...
# 356  Single-player,Multi-player,Co-op,Shared/Split ...
#
#                                                   tags purchase_date  \
# 0    Indie,Adventure,Story Rich,Casual,Atmospheric,...   Jul 2, 2018
# 1    Mod,Utilities,RPG,Game Development,Singleplaye...  Nov 26, 2016
# 2    Point & Click,Adventure,Story Rich,Comedy,Indi...   Jul 2, 2018
# 3    Medieval,RPG,Open World,Strategy,Sandbox,Actio...  Nov 28, 2016
# 4    Tower Defense,Co-op,Action,Strategy,Online Co-...   Mar 4, 2018
# 5    RPG,Open World,Survival,Co-op,Fantasy,Online C...  Jun 27, 2019
# 6    Great Soundtrack,Action,Violent,Indie,Top-Down...  Feb 16, 2018
# 7                  VR,Simulation,Utilities,Multiplayer  Jan 29, 2018
# 8    RPG,Turn-Based,Adventure,Fantasy,Great Soundtr...  Nov 23, 2018
# 9    Action,Adventure,VR,Shooter,Puzzle,FPS,First-P...  Dec 22, 2017
# 10   Action,Adventure,Hack and Slash,Third Person,S...  Jan 30, 2018
# 11   RPG,Post-apocalyptic,Classic,Turn-Based,Advent...  Jun 23, 2017
# 12                               Action,VR,Multiplayer  Jul 20, 2019
# 13   Action,Multiplayer,Adventure,Rogue-like,Co-op,...   Oct 9, 2016
# 14   Local Co-Op,Local Multiplayer,Co-op,Multiplaye...  Jun 13, 2018
# 15   Space,Simulation,Free to Play,Multiplayer,Onli...  Sep 16, 2017
# 16   RPG,Action RPG,Hack and Slash,Co-op,Dungeon Cr...  Jan 13, 2018
# 17   Space,Simulation,Sandbox,Physics,Science,Space...  May 30, 2019
# 18   Space,Strategy,Grand Strategy,Sci-fi,4X,Real-T...  Feb 18, 2018
# 19   Strategy,Indie,Simulation,Space,Sci-fi,Moddabl...  Dec 21, 2018
# 20   Racing,Offroad,Motocross,Multiplayer,Sports,Si...  Jan 30, 2018
# 21   Strategy,4X,Turn-Based,Turn-Based Strategy,Fan...  Nov 28, 2016
# 22   Atmospheric,Psychological,Story Rich,Female Pr...  May 16, 2018
# 23                        Casual,Indie,VR,Free to Play  Nov 19, 2017
# 24   Strategy,Space,Sci-fi,4X,Multiplayer,Turn-Base...   Apr 2, 2019
# 25   RPG,Sci-fi,Story Rich,Third-Person Shooter,Act...   May 9, 2018
# 26   Choices Matter,Medieval,Card Game,Indie,Choose...   Dec 9, 2017
# 27   Adventure,Point & Click,Classic,Comedy,Story R...  Jun 27, 2019
# 28   Strategy,Simulation,Indie,Sci-fi,Space,2D,Sand...  Dec 21, 2018
# 29   Difficult,Cartoon,Great Soundtrack,Platformer,...   Oct 2, 2017
# ..                                                 ...           ...
# 327  RPG,Open World,Hack and Slash,Action RPG,Multi...   Apr 4, 2017
# 328  Visual Novel,Adventure,Indie,RPG,Choices Matte...  Mar 15, 2018
# 329  Adventure,Action,Open World,Sci-fi,Remake,Thir...  Oct 30, 2018
# 330  Action,Sci-fi,Platformer,Metroidvania,Comedy,S...   May 9, 2018
# 331  Cute,3D Platformer,Great Soundtrack,Female Pro...  Jun 28, 2019
# 332  Early Access,VR,Free to Play,Memes,Anime,Funny...  Feb 27, 2018
# 333  Action,Top-Down,Beat 'em up,Indie,Gore,Fightin...  Jun 27, 2019
# 334  RPG,Comedy,Adventure,Funny,Turn-Based,Dark Hum...  Jun 28, 2019
# 335  Point & Click,Adventure,Classic,Horror,Retro,B...  Feb 27, 2019
# 336  VR,Action,Space,Great Soundtrack,Shooter,First...  Nov 19, 2017
# 337  Stealth,Action,First-Person,Female Protagonist...  Jul 24, 2019
# 338  Batman,Superhero,Story Rich,Choices Matter,Adv...   Feb 5, 2018
# 339  Adventure,Point & Click,Comedy,Puzzle,Singlepl...   Nov 9, 2016
# 340  Action,Indie,Twin Stick Shooter,VR,Platformer,...   Mar 4, 2018
# 341  Free to Play,Walking Simulator,First-Person,In...   Dec 3, 2016
# 342  Adventure,Point & Click,Comedy,Singleplayer,Pu...  Nov 13, 2016
# 343  Adventure,Point & Click,Indie,Female Protagoni...  Apr 21, 2018
# 344  RPG,Cyberpunk,Turn-Based,Isometric,Sci-fi,Indi...  Oct 28, 2017
# 345  Card Game,Rogue-like,Turn-Based,Strategy,Singl...   Dec 4, 2017
# 346  Story Rich,Indie,Great Soundtrack,RPGMaker,Adv...  Feb 27, 2019
# 347  Open World,Shooter,Action,Co-op,Multiplayer,Ta...  Feb 16, 2018
# 348  Adventure,Indie,Interactive Fiction,Casual,Bas...  Mar 28, 2019
# 349  Pixel Graphics,Zombies,Action,Rogue-like,Survi...  Mar 25, 2017
# 350  Quick-Time Events,Rome,Action,Hack and Slash,T...  Jan 23, 2018
# 351  Indie,Adventure,Action,Action-Adventure,Explor...  Nov 17, 2018
# 352                        Simulation,Action,VR,Flight  Nov 24, 2017
# 353  Batman,Action,Open World,Superhero,Stealth,Adv...  Aug 15, 2018
# 354  Action,Hack and Slash,Adventure,RPG,Open World...  Jan 30, 2018
# 355  Action,FPS,Adventure,Shooter,Cyberpunk,Robots,...  Sep 23, 2017
# 356  Strategy,Turn-Based Strategy,Indie,Grand Strat...   Mar 5, 2018
#
#      release_date  total_positive_reviews  total_negative_reviews  \
# 0    10 Dec, 2013              372.000000               96.000000
# 1    12 Aug, 2015               23.000000                0.000000
# 2    28 Jan, 2014             3018.000000              663.000000
# 3    31 Mar, 2010            63078.000000             1746.000000
# 4    30 Jul, 2012             8841.000000              523.000000
# 5    26 Mar, 2019            15356.115493             3348.991549
# 6    23 Oct, 2012            39776.000000             1035.000000
# 7    28 Apr, 2016               33.000000                3.000000
# 8    25 Feb, 2014             1875.000000               39.000000
# 9    17 Oct, 2017               47.000000               11.000000
# 10   23 Sep, 2010             5893.000000              700.000000
# 11   13 Nov, 2013              148.000000               35.000000
# 12   11 Dec, 2018              110.000000              260.000000
# 13   31 Aug, 2016             9659.000000             1058.000000
# 14    3 Aug, 2016             5871.000000              551.000000
# 15    6 Jul, 2010              167.000000               30.000000
# 16   20 Sep, 2012            21566.000000             1289.000000
# 17   27 Apr, 2015            43103.000000             4042.000000
# 18    9 May, 2016            30934.000000             7777.000000
# 19   16 Apr, 2015               74.000000              115.000000
# 20   26 Nov, 2010             1122.000000              248.000000
# 21   18 Sep, 2014             8406.000000             1780.000000
# 22    7 Aug, 2017            20437.000000             1847.000000
# 23    3 Jun, 2016                2.000000                0.000000
# 24   18 May, 2017             6812.000000             1458.000000
# 25   28 Jan, 2010             9566.000000              517.000000
# 26   11 Aug, 2016             5001.000000              597.000000
# 27   26 Jan, 2015             3457.000000              372.000000
# 28   16 Nov, 2009              329.000000               73.000000
# 29   29 Sep, 2017            36322.000000             1542.000000
# ..            ...                     ...                     ...
# 327  21 Dec, 2012              845.000000              333.000000
# 328  10 Jul, 2014             1688.000000              233.000000
# 329  14 Nov, 2017              251.000000               35.000000
# 330  25 Jul, 2016              378.000000               42.000000
# 331   5 Oct, 2017            15943.000000              296.000000
# 332   1 Feb, 2017              135.000000               29.000000
# 333   1 Aug, 2017              854.000000              204.000000
# 334   5 Mar, 2014            27271.000000              741.000000
# 335  17 Oct, 2013              730.000000               90.000000
# 336  12 Oct, 2017             1949.000000               94.000000
# 337  14 Sep, 2017             2292.000000              463.000000
# 338   2 Aug, 2016             5034.000000             1589.000000
# 339   6 Aug, 2012             5641.000000              687.000000
# 340   3 Sep, 2015               58.000000                0.000000
# 341  31 May, 2016               42.000000               32.000000
# 342   6 Nov, 2012             1142.000000              108.000000
# 343   2 Jul, 2015              609.000000               92.000000
# 344  25 Jul, 2013             6383.000000              833.000000
# 345  23 Jan, 2019            31062.000000             1077.000000
# 346  10 May, 2017             1975.000000               44.000000
# 347   6 Mar, 2017            23338.000000             7681.000000
# 348  25 Apr, 2013              263.000000               63.000000
# 349  21 Jul, 2016             3083.000000              202.000000
# 350  10 Oct, 2014            11922.000000             2303.000000
# 351   5 May, 2017              106.000000               23.000000
# 352  20 Dec, 2016              150.000000               91.000000
# 353  23 Jun, 2015            19008.000000             4849.000000
# 354   5 Nov, 2015             5099.000000             1719.000000
# 355   3 Jun, 2016              718.000000              159.000000
# 356   5 Dec, 2013              915.000000              102.000000
#
#      waiting_days  own_days
# 0            1665       541
# 1             472      1124
# 2            1616       541
# 3            2434      1122
# 4            2043       661
# 5              93       181
# 6            1942       677
# 7             641       695
# 8            1732       397
# 9              66       733
# 10           2686       694
# 11           1318       915
# 12            221       158
# 13             39      1172
# 14            679       560
# 15           2629       830
# 16           1941       711
# 17           1494       209
# 18            650       675
# 19           1345       369
# 20           2622       694
# 21            802      1122
# 22            282       588
# 23            534       766
# 24            684       267
# 25           3023       595
# 26            485       746
# 27           1613       181
# 28           3322       369
# 29              3       814
# ..            ...       ...
# 327          1565       995
# 328          1344       650
# 329           350       421
# 330           653       595
# 331           631       180
# 332           391       666
# 333           695       181
# 334          1941       180
# 335          1959       301
# 336            38       766
# 337           678       154
# 338           552       688
# 339          1556      1141
# 340           913       661
# 341           186      1117
# 342          1468      1137
# 343          1024       613
# 344          1556       788
# 345             0       751
# 346           658       301
# 347           347       677
# 348          2163       272
# 349           247      1005
# 350          1201       701
# 351           561       403
# 352           339       761
# 353          1149       497
# 354           817       694
# 355           477       823
# 356          1551       660
#
# [357 rows x 12 columns]

# %%
train['is_free'] = train['is_free'].astype(int)
test['is_free'] = test['is_free'].astype(int)

# %%
drop_columns = ['purchase_date', 'release_date']

train_rough = train.drop(columns=drop_columns)
# test_rough = test.drop(columns=drop_columns + ['playtime_forever'])
test_rough = test.drop(columns=drop_columns)

# %%
train_rough.drop(train_rough.price.nlargest(2).index, inplace=True)

# %%
y = train_rough['playtime_forever']

from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(train_rough, y, random_state = 0, test_size=0.2)

# %%
train_X
# Out:
#      playtime_forever  is_free    price  \
# 299          2.883333        0   8800.0
# 248          0.000000        0  13500.0
# 310          0.000000        0   7800.0
# 338          0.000000        0   5000.0
# 142          0.500000        0    800.0
# 21           1.616667        0   8800.0
# 341          0.616667        1      0.0
# 141          0.000000        0  11200.0
# 49           0.400000        1      0.0
# 311          0.000000        0   6800.0
# 297          0.000000        0   7900.0
# 270          1.766667        0  10300.0
# 181          0.333333        0   5700.0
# 261          0.000000        0  11200.0
# 102          2.800000        0   3600.0
# 22           0.000000        0   8800.0
# 122          0.500000        0   7000.0
# 89           3.083333        0  16800.0
# 144          0.000000        0  11600.0
# 132          0.633333        0   6800.0
# 66           0.000000        0   5000.0
# 262          0.000000        0   6800.0
# 12           0.000000        1      0.0
# 120          2.300000        0   6800.0
# 153          0.166667        0   8800.0
# 322          1.366667        1      0.0
# 276          1.350000        0   4800.0
# 17           0.000000        0  11200.0
# 232          0.000000        0   9000.0
# 285          0.733333        0   6200.0
# ..                ...      ...      ...
# 177          0.083333        0   3600.0
# 99           0.000000        0   4200.0
# 197         92.633333        0  13300.0
# 244          9.016667        0   5900.0
# 115          0.200000        0   9900.0
# 266          5.116667        1      0.0
# 72           1.100000        0   3600.0
# 25           0.000000        0   9900.0
# 165          0.000000        0   4800.0
# 342          1.116667        0   7900.0
# 174          0.000000        0   6800.0
# 344          0.050000        0   4800.0
# 39           3.083333        0   4800.0
# 193          0.000000        0   5800.0
# 316          0.000000        0  11200.0
# 88           0.000000        1      0.0
# 70           0.000000        0   2600.0
# 87           0.000000        0   6800.0
# 293          0.000000        0   3400.0
# 243          0.000000        0   9000.0
# 278          0.000000        0  19000.0
# 211          0.000000        0  11600.0
# 9            0.016667        0   8800.0
# 195          2.116667        0   3500.0
# 252          3.116667        0   4700.0
# 325          3.150000        0   9000.0
# 192          6.316667        0  20800.0
# 117          0.000000        0   6800.0
# 47           0.000000        0  11000.0
# 172          0.000000        0  13400.0
#
#                                                 genres  \
# 299                                           Strategy
# 248                                   Action,Adventure
# 310                                 Indie,RPG,Strategy
# 338                                          Adventure
# 142                        Casual,Indie,RPG,Simulation
# 21                                        RPG,Strategy
# 341                                 Free to Play,Indie
# 141                             Action,Adventure,Indie
# 49   Casual,Free to Play,Massively Multiplayer,Simu...
# 311                          Action,Indie,RPG,Strategy
# 297                                    Adventure,Indie
# 270                          Indie,Simulation,Strategy
# 181                          Indie,Simulation,Strategy
# 261                                Action,RPG,Strategy
# 102                               Action,Adventure,RPG
# 22                              Action,Adventure,Indie
# 122                                   Indie,Simulation
# 89                                    Action,Adventure
# 144                                     Indie,Strategy
# 132                                             Action
# 66                                        Action,Indie
# 262                                          Adventure
# 12                                              Action
# 120                              Design & Illustration
# 153                              Action,RPG,Simulation
# 322                       Adventure,Indie,RPG,Strategy
# 276                             Action,Adventure,Indie
# 17                                    Indie,Simulation
# 232                                    Adventure,Indie
# 285                                       Action,Indie
# ..                                                 ...
# 177                                          Indie,RPG
# 99                               Action,Indie,Strategy
# 197                             Adventure,RPG,Strategy
# 244                                                RPG
# 115                                         Action,RPG
# 266                          Action,Free to Play,Indie
# 72                            Adventure,Indie,Strategy
# 25                                                 RPG
# 165                                       Action,Indie
# 342                                    Adventure,Indie
# 174                             Action,Adventure,Indie
# 344                       Adventure,Indie,RPG,Strategy
# 39                       Action,Adventure,Casual,Indie
# 193                       Adventure,Indie,RPG,Strategy
# 316                                             Action
# 88                                              Action
# 70                                     Adventure,Indie
# 87                                              Action
# 293                  Adventure,Casual,Indie,Simulation
# 243  Sexual Content,Nudity,Violent,Gore,Action,Adve...
# 278                                           Strategy
# 211                                    Action,Strategy
# 9                                     Action,Adventure
# 195                                    Adventure,Indie
# 252                      Action,Adventure,Casual,Indie
# 325                                              Indie
# 192                                   Action,Adventure
# 117                                             Action
# 47                                Action,Adventure,RPG
# 172                                Simulation,Strategy
#
#                                             categories  \
# 299                          Single-player,Steam Cloud
# 248  Single-player,Steam Achievements,Full controll...
# 310  Single-player,Steam Achievements,Steam Trading...
# 338  Single-player,Steam Achievements,Full controll...
# 142  Single-player,Steam Achievements,Steam Trading...
# 21   Single-player,Multi-player,Online Multi-Player...
# 341              Single-player,Full controller support
# 141  Single-player,Steam Achievements,Steam Worksho...
# 49   Single-player,Multi-player,Online Multi-Player...
# 311  Single-player,Steam Achievements,Full controll...
# 297  Single-player,Steam Achievements,Steam Trading...
# 270           Single-player,Steam Workshop,Steam Cloud
# 181  Single-player,Local Multi-Player,Co-op,Local C...
# 261  Single-player,Multi-player,Steam Achievements,...
# 102                                      Single-player
# 22   Single-player,Steam Achievements,Full controll...
# 122  Single-player,Steam Achievements,Steam Trading...
# 89   Single-player,Multi-player,Steam Achievements,...
# 144  Single-player,Multi-player,Online Multi-Player...
# 132  Single-player,Multi-player,Co-op,Online Co-op,...
# 66   Single-player,Co-op,Steam Achievements,Full co...
# 262  Single-player,Steam Achievements,Full controll...
# 12   Single-player,Multi-player,Online Multi-Player...
# 120                    VR Support,SteamVR Collectibles
# 153  Single-player,Steam Achievements,Full controll...
# 322  Single-player,Steam Achievements,Captions avai...
# 276  Single-player,Steam Achievements,Full controll...
# 17   Single-player,Steam Trading Cards,Steam Worksh...
# 232  Single-player,Multi-player,Online Multi-Player...
# 285  Single-player,Steam Achievements,Steam Cloud,S...
# ..                                                 ...
# 177  Single-player,Multi-player,Co-op,Shared/Split ...
# 99   Single-player,Steam Achievements,Full controll...
# 197  Single-player,Multi-player,Online Multi-Player...
# 244                          Single-player,Steam Cloud
# 115                                      Single-player
# 266  Multi-player,Online Multi-Player,Cross-Platfor...
# 72   Single-player,Steam Achievements,Full controll...
# 25                                       Single-player
# 165  Single-player,Steam Achievements,Partial Contr...
# 342  Single-player,Steam Achievements,Steam Trading...
# 174  Single-player,Steam Achievements,Full controll...
# 344  Single-player,Steam Trading Cards,Steam Worksh...
# 39   Single-player,Multi-player,Online Multi-Player...
# 193  Single-player,Online Multi-Player,Steam Achiev...
# 316  Single-player,Multi-player,Steam Achievements,...
# 88   Single-player,Steam Achievements,Full controll...
# 70            Single-player,Partial Controller Support
# 87                     Single-player,Co-op,Steam Cloud
# 293  Single-player,Steam Achievements,Steam Trading...
# 243  Single-player,Steam Achievements,Full controll...
# 278  Single-player,Multi-player,Cross-Platform Mult...
# 211  Single-player,Multi-player,Online Multi-Player...
# 9    Single-player,Steam Achievements,SteamVR Colle...
# 195  Single-player,Steam Achievements,Full controll...
# 252  Single-player,Steam Achievements,Steam Trading...
# 325                   Single-player,Steam Leaderboards
# 192  Single-player,Steam Trading Cards,Partial Cont...
# 117  Single-player,Multi-player,Steam Achievements,...
# 47   Single-player,Steam Achievements,Full controll...
# 172  Single-player,Multi-player,Co-op,Cross-Platfor...
#
#                                                   tags  \
# 299                                           Strategy
# 248  Action,Hack and Slash,Great Soundtrack,Spectac...
# 310  Turn-Based Combat,Dark Fantasy,Dungeon Crawler...
# 338  Batman,Superhero,Story Rich,Choices Matter,Adv...
# 142  Simulation,Indie,Relaxing,Casual,Singleplayer,...
# 21   Strategy,4X,Turn-Based,Turn-Based Strategy,Fan...
# 341  Free to Play,Walking Simulator,First-Person,In...
# 141      Adventure,VR,Action,Puzzle,Indie,First-Person
# 49   Free to Play,VR,Casual,Simulation,Massively Mu...
# 311  Indie,Action,RPG,Rogue-lite,Strategy,Card Game...
# 297  Point & Click,Adventure,Dark Humor,Comedy,Sing...
# 270  Base Building,Survival,Strategy,Sandbox,Manage...
# 181  Strategy,Indie,Pixel Graphics,Simulation,Polit...
# 261  Strategy,RPG,Dragons,Fantasy,Political,Action,...
# 102  Adventure,Point & Click,Female Protagonist,Sto...
# 22   Atmospheric,Psychological,Story Rich,Female Pr...
# 122  Simulation,Building,Singleplayer,Education,Rea...
# 89   Anime,Fighting,Action,Ninja,Multiplayer,Advent...
# 144  Strategy,Space,RTS,Sci-fi,4X,Multiplayer,Modda...
# 132  Co-op,Online Co-Op,Local Co-Op,Twin Stick Shoo...
# 66   Action,Indie,Surreal,Beat 'em up,Fighting,Firs...
# 262  Puzzle,First-Person,Female Protagonist,Space,S...
# 12                               Action,VR,Multiplayer
# 120  Design & Illustration,VR,Hand-drawn,Singleplay...
# 153  Zombies,Survival,Open World,Base Building,Acti...
# 322  RPG,Post-apocalyptic,Turn-Based,Strategy,Tacti...
# 276  Zombies,Platformer,Indie,Action,Post-apocalypt...
# 17   Space,Simulation,Sandbox,Physics,Science,Space...
# 232    Adventure,Violent,Gore,Indie,VR,FPS,Multiplayer
# 285  Platformer,Action,FPS,Indie,Difficult,Parkour,...
# ..                                                 ...
# 177  RPG,Indie,Hack and Slash,Co-op,Level Editor,Dr...
# 99   Action,Indie,Strategy,Pixel Graphics,Mythology...
# 197  RPG,Story Rich,Turn-Based,Co-op,Fantasy,Charac...
# 244  Open World,RPG,Fantasy,Singleplayer,Moddable,F...
# 115  RPG,Sci-fi,Story Rich,Action,Third-Person Shoo...
# 266  Free to Play,Multiplayer,2D,Action,Platformer,...
# 72   Indie,Dystopian,Choices Matter,Strategy,Atmosp...
# 25   RPG,Sci-fi,Story Rich,Third-Person Shooter,Act...
# 165  FPS,Cyberpunk,Action,Sci-fi,Shooter,Indie,Sing...
# 342  Adventure,Point & Click,Comedy,Singleplayer,Pu...
# 174  Adventure,First-Person,Exploration,Parkour,Sin...
# 344  RPG,Cyberpunk,Turn-Based,Isometric,Sci-fi,Indi...
# 39   Comedy,Co-op,Funny,Platformer,Multiplayer,Loca...
# 193  Board Game,Turn-Based Strategy,Multiplayer,Str...
# 316  Nudity,Sexual Content,Anime,Mature,Action,Fema...
# 88   Platformer,Great Soundtrack,Action,Fast-Paced,...
# 70   Exploration,Walking Simulator,Horror,Adventure...
# 87   Action,FPS,Shooter,Co-op,Singleplayer,Multipla...
# 293  FMV,Adventure,Indie,Casual,Simulation,Lovecraf...
# 243  Horror,Psychological Horror,Survival Horror,Fi...
# 278  Strategy,Turn-Based,Tactical,Turn-Based Strate...
# 211  Strategy,RTS,Multiplayer,Space,Base Building,R...
# 9    Action,Adventure,VR,Shooter,Puzzle,FPS,First-P...
# 195  Adventure,Atmospheric,Story Rich,Walking Simul...
# 252  Action,Adventure,Indie,Casual,Visual Novel,Fem...
# 325  VR,Rhythm,Music,Great Soundtrack,Indie,Fast-Pa...
# 192  Open World,Survival,Action,Adventure,Hunting,F...
# 117  Open World,Action,Destruction,Physics,Sci-fi,T...
# 47   Detective,Adventure,Horror,Mystery,Supernatura...
# 172  Strategy,RTS,Villain Protagonist,Fantasy,Simul...
#
#      total_positive_reviews  total_negative_reviews  waiting_days  own_days
# 299                   114.0                    29.0           229       521
# 248                  9066.0                   562.0          2303       223
# 310                 41141.0                  6291.0          1128       308
# 338                  5034.0                  1589.0           552       688
# 142                  9318.0                  1194.0           390      1565
# 21                   8406.0                  1780.0           802      1122
# 341                    42.0                    32.0           186      1117
# 141                   365.0                    55.0           187       612
# 49                     14.0                     4.0           595       769
# 311                   363.0                    67.0          1196       170
# 297                  1326.0                   139.0          1485      1141
# 270                 36004.0                   820.0             0       814
# 181                   514.0                   222.0             0       748
# 261                   970.0                   357.0          2096       236
# 102                  1015.0                    94.0          3594      1027
# 22                  20437.0                  1847.0           282       588
# 122                  8121.0                   850.0            92       238
# 89                  14647.0                  3002.0           662       758
# 144                  5791.0                   480.0          2100       652
# 132                 10595.0                   888.0          1081       398
# 66                    388.0                    93.0          1642       788
# 262                  2418.0                   384.0           737       475
# 12                    110.0                   260.0           221       158
# 120                   333.0                    24.0           593       766
# 153                  3533.0                  1092.0          1151       552
# 322                     0.0                     0.0          1009       915
# 276                  6607.0                  1674.0          1707       910
# 17                  43103.0                  4042.0          1494       209
# 232                   244.0                    99.0           350       181
# 285                  1171.0                   187.0           985       910
# ..                      ...                     ...           ...       ...
# 177                   757.0                   195.0           725      1122
# 99                    408.0                    82.0           631       593
# 197                 47530.0                  2488.0            81       751
# 244                 11989.0                   738.0          3129       715
# 115                  9674.0                   639.0          3428       595
# 266                    61.0                     7.0            19      1565
# 72                   9347.0                   971.0           530       611
# 25                   9566.0                   517.0          3023       595
# 165                  2492.0                   498.0          1899       823
# 342                  1142.0                   108.0          1468      1137
# 174                  4075.0                   397.0           421       797
# 344                  6383.0                   833.0          1556       788
# 39                  36408.0                  1063.0           922      1128
# 193                  5683.0                  1359.0          1070       506
# 316                  2800.0                   129.0           775       238
# 88                   5016.0                   425.0          2825       149
# 70                    827.0                    99.0           421       552
# 87                    331.0                   203.0          3623       694
# 293                   213.0                    44.0           636       314
# 243                 10303.0                  1437.0           338       637
# 278                 21211.0                  4645.0          1280       140
# 211                  4711.0                  1142.0          1420       170
# 9                      47.0                    11.0            66       733
# 195                 32156.0                  5298.0           624       791
# 252                   175.0                    25.0           221       648
# 325                 15327.0                   949.0             0       603
# 192                  8351.0                  2488.0           984       411
# 117                  5190.0                   553.0          3059       694
# 47                   5396.0                   954.0          1243       788
# 172                  6992.0                   423.0           622       181
#
# [284 rows x 10 columns]

# %%
generes_list = train_X['genres'].str.split(',',expand=False).to_numpy()
categories_list = train_X['categories'].str.split(',',expand=False).to_numpy()
tags_list = train_X['tags'].str.split(',',expand=False).to_numpy()

generes_set = {item for i in generes_list for item in i}
categories_set = {item for i in categories_list for item in i}
tags_set = {item for i in tags_list for item in i}

generes_time_dict = {}
categories_time_dict = {}
tags_time_dict = {}

# generate the mean of time corresponding to different tags
for genere in generes_set:
    count = np.sum(train_X['genres'].str.contains(genere))
    generes_time_dict[genere] = np.sum(train_X[train_X['genres'].str.contains(genere)].playtime_forever) / len(train_X)

for category in categories_set:
    count = np.sum(train_X['categories'].str.contains(category))
    categories_time_dict[category] = np.sum(train_X[train_X['categories'].str.contains(category)].playtime_forever) / len(train_X)

for tag in tags_set:
    count = np.sum(train_X['tags'].str.contains(tag))
    tags_time_dict[tag] = np.sum(train_X[train_X['tags'].str.contains(tag)].playtime_forever) / len(train_X)

# %%
def find_mean(current_dict, current_str):
    str_list = current_str.split(',')
    num_list = [0]
    for item in str_list:
        if item in current_dict:
            num_list.append(current_dict[item])
    return np.mean(num_list)

# %%
generes_time_dict
# Out:
# {'Utilities': 0.018016431924882628,
#  'Design & Illustration': 0.026115023474178403,
#  'Action': 1.759037558685446,
#  'Casual': 0.06420187793427229,
#  'Indie': 1.4561619718309857,
#  'Nudity': 0.0,
#  'Audio Production': 0.00011737089201877934,
#  'Simulation': 0.6647887323943661,
#  'Early Access': 0.011619718309859155,
#  'Massively Multiplayer': 0.538262910798122,
#  'Sexual Content': 0.022887323943661973,
#  'Violent': 0.022887323943661973,
#  'Adventure': 2.3171948356807515,
#  'Racing': 0.004929577464788732,
#  'Strategy': 0.983450704225352,
#  'Sports': 0.008509389671361504,
#  'RPG': 1.188556338028169,
#  'Animation & Modeling': 0.018016431924882628,
#  'Free to Play': 0.028931924882629103,
#  'Gore': 0.0}

# %%
train_X['genres_time_mean'] = train_X['genres'].apply(lambda x: find_mean(generes_time_dict, x))
train_X['categories_time_mean'] = train_X['categories'].apply(lambda x: find_mean(categories_time_dict, x))
# train_X['tags_time_mean'] = train_X['tags'].apply(lambda x: find_mean(tags_time_dict, x))

val_X['genres_time_mean'] = val_X['genres'].apply(lambda x: find_mean(generes_time_dict, x))
val_X['categories_time_mean'] = val_X['categories'].apply(lambda x: find_mean(categories_time_dict, x))
# val_X['tags_time_mean'] = val_X['tags'].apply(lambda x: find_mean(tags_time_dict, x))

test_X = test_rough
test_X['genres_time_mean'] = test_rough['genres'].apply(lambda x: find_mean(generes_time_dict, x))
test_X['categories_time_mean'] = test_rough['categories'].apply(lambda x: find_mean(categories_time_dict, x))
# test_X['tags_time_mean'] = test_rough['tags'].apply(lambda x: find_mean(tags_time_dict, x))

# %%
# train_X['categories_count'] = train_X['categories'].apply(lambda x: len(x.split(',')))
# val_X['categories_count'] = val_X['categories'].apply(lambda x: len(x.split(',')))
# test_X['categories_count'] = test_X['categories'].apply(lambda x: len(x.split(',')))

train_X['tags_count'] = train_X['tags'].apply(lambda x: len(x.split(',')))
val_X['tags_count'] = val_X['tags'].apply(lambda x: len(x.split(',')))
test_X['tags_count'] = test_X['tags'].apply(lambda x: len(x.split(',')))

# train_X['genres_count'] = train_X['genres'].apply(lambda x: len(x.split(',')))
# val_X['genres_count'] = val_X['genres'].apply(lambda x: len(x.split(',')))
# test_X['genres_count'] = test_X['genres'].apply(lambda x: len(x.split(',')))

# %%
train_X = train_X.select_dtypes(exclude=['object'])
val_X = val_X.select_dtypes(exclude=['object'])
test_X = test_X.select_dtypes(exclude=['object'])

# %%
train_X.describe()
# Out:
#        playtime_forever     is_free         price  total_positive_reviews  \
# count        284.000000  284.000000    284.000000              284.000000
# mean           3.174061    0.070423   6980.982394            13760.461674
# std           12.060766    0.256309   5198.560988            40452.448590
# min            0.000000    0.000000      0.000000                0.000000
# 25%            0.000000    0.000000   3600.000000              787.750000
# 50%            0.050000    0.000000   6750.000000             2894.500000
# 75%            1.445833    0.000000   9000.000000             9403.250000
# max          113.800000    1.000000  30800.000000           440902.000000
#
#        total_negative_reviews  waiting_days     own_days  genres_time_mean  \
# count               284.00000    284.000000   284.000000        284.000000
# mean               3459.84152   1009.454225   639.095070          1.000892
# std               27343.40263    885.365674   288.225768          0.303759
# min                   0.00000      0.000000   136.000000          0.002465
# 25%                 119.50000    360.250000   421.750000          0.776100
# 50%                 414.00000    791.500000   643.000000          1.071733
# 75%                1124.50000   1472.000000   797.000000          1.257786
# max              436046.00000   4320.000000  1565.000000          1.383099
#
#        categories_time_mean  tags_count
# count            284.000000  284.000000
# mean               1.575054   17.316901
# std                0.281313    4.715765
# min                0.018349    1.000000
# 25%                1.402641   16.750000
# 50%                1.607584   20.000000
# 75%                1.837289   20.000000
# max                1.938758   20.000000

# %%
test_X.describe()
# Out:
#          is_free         price  total_positive_reviews  \
# count  90.000000     90.000000               90.000000
# mean    0.066667   6213.311111            11146.727273
# std     0.250841   4860.918274            23965.791872
# min     0.000000      0.000000                0.000000
# 25%     0.000000   3600.000000              591.750000
# 50%     0.000000   6150.000000             1918.000000
# 75%     0.000000   7725.000000             9344.500000
# max     1.000000  26800.000000           149032.000000
#
#        total_negative_reviews  waiting_days     own_days  genres_time_mean  \
# count               90.000000     90.000000    90.000000         90.000000
# mean              1656.602273    998.966667   659.166667          0.996756
# std               5656.019825    889.486955   242.933720          0.306267
# min                  0.000000      0.000000   151.000000          0.014466
# 25%                 86.000000    334.000000   526.500000          0.825191
# 50%                293.500000    686.000000   662.000000          0.982531
# 75%               1104.000000   1278.500000   785.000000          1.257786
# max              51387.000000   3850.000000  1164.000000          1.383099
#
#        categories_time_mean  tags_count
# count             90.000000   90.000000
# mean               1.601064   17.311111
# std                0.263590    4.433388
# min                0.694577    4.000000
# 25%                1.402641   15.250000
# 50%                1.637676   20.000000
# 75%                1.853958   20.000000
# max                1.932500   20.000000

# %%
train_X = train_X.drop(columns=['playtime_forever'])
val_X = val_X.drop(columns=['playtime_forever'])

# %%
# norm it
train_x_norm = (train_X - train_X.min()) / (train_X.max() - train_X.min())
val_x_norm = (val_X - val_X.min()) / (val_X.max() - val_X.min())
test_x_norm = (test_X - test_X.min()) / (test_X.max() - test_X.min())

# %%
test_X.describe()
# Out:
#          is_free         price  total_positive_reviews  \
# count  90.000000     90.000000               90.000000
# mean    0.066667   6213.311111            11146.727273
# std     0.250841   4860.918274            23965.791872
# min     0.000000      0.000000                0.000000
# 25%     0.000000   3600.000000              591.750000
# 50%     0.000000   6150.000000             1918.000000
# 75%     0.000000   7725.000000             9344.500000
# max     1.000000  26800.000000           149032.000000
#
#        total_negative_reviews  waiting_days     own_days  genres_time_mean  \
# count               90.000000     90.000000    90.000000         90.000000
# mean              1656.602273    998.966667   659.166667          0.996756
# std               5656.019825    889.486955   242.933720          0.306267
# min                  0.000000      0.000000   151.000000          0.014466
# 25%                 86.000000    334.000000   526.500000          0.825191
# 50%                293.500000    686.000000   662.000000          0.982531
# 75%               1104.000000   1278.500000   785.000000          1.257786
# max              51387.000000   3850.000000  1164.000000          1.383099
#
#        categories_time_mean  tags_count
# count             90.000000   90.000000
# mean               1.601064   17.311111
# std                0.263590    4.433388
# min                0.694577    4.000000
# 25%                1.402641   15.250000
# 50%                1.637676   20.000000
# 75%                1.853958   20.000000
# max                1.932500   20.000000

# %%
test_x_norm

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt

forest_model = RandomForestRegressor(n_estimators=80, criterion='mae', oob_score=True, random_state=1, max_depth = 2)
forest_model.fit(train_X, train_y)
forest_rough_preds = forest_model.predict(train_X)
print(sqrt(mean_squared_error(train_y, forest_rough_preds)))
forest_rough_preds = forest_model.predict(val_X)
print(sqrt(mean_squared_error(val_y, forest_rough_preds)))

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(n_estimators=60,
                    learning_rate = .01,
                    max_depth = 4,
                    random_state=8889,
                    n_jobs = -1,
                    early_stopping_rounds=10)
xgb_model.fit(train_x_norm, train_y)
xgb_rough_preds = xgb_model.predict(train_x_norm)
print(sqrt(mean_squared_error(train_y, xgb_rough_preds)))
xgb_rough_preds = xgb_model.predict(val_x_norm)
print(sqrt(mean_squared_error(val_y, xgb_rough_preds)))

# %%
test_rough_predict = xgb_model.predict(test_x_norm)
output = pd.DataFrame(pd.DataFrame({
        "id": test_with_id.id,
        "playtime_forever": test_rough_predict
    }))


output.to_csv("xgb_submission.csv", index = False)
